# %% [markdown]
# ### Importing Nessecary Libraries

# %%
import numpy as np
from numpy import mean
import pandas as pd 
import datetime 
import matplotlib.pyplot as plt
import plotly.express as px 
import seaborn as sns

# %% [markdown]
# ### Reading and Concatinating the Alumni Data Set

# %%
#Merging all sheets into one dataframe 
datafinal = pd.concat(pd.read_excel('UMD Alumni Association Dataset.xlsx', sheet_name=None,header=0), ignore_index=True)
datafinal

#Code : https://pbpython.com/pandas-excel-tabs.html
#622 rows and 17 columns
# Out:
#                                             Event Name  ... Percentage Major Prospect
# 0                              Ocean City Summer Party  ...                  0.190476
# 1    Neurodiversity on Campus and in the Workplace ...  ...                  0.000000
# 2                                Northern NJ Terps TPN  ...                  0.071429
# 3    Philly Terps: Young Alumni Happy Hour Summer S...  ...                  0.000000
# 4             Philly Terps Suite Night at the Ballpark  ...                  0.000000
# ..                                                 ...  ...                       ...
# 617                 Baltimore Orioles Bullpen Pregame   ...                  0.000000
# 618                                      50th Reunion   ...                  0.355263
# 619                                     Ring Ceremony   ...                  0.058824
# 620                                  Terps on the Hill  ...                  0.135593
# 621                NY Terps Alumnae Networking Dinner   ...                  0.204545
#
# [622 rows x 14 columns]

# %% [markdown]
# ### Data Cleansing

# %%
datafinal[['Area', 'City']] = datafinal['Location Description'].str.split('-', expand=True)
datafinal[['Group', 'Type']] = datafinal['Group Description'].str.split('-', expand=True)
print(datafinal)
# Out:
#                                             Event Name  ...        Type
# 0                              Ocean City Summer Party  ...     General
# 1    Neurodiversity on Campus and in the Workplace ...  ...     General
# 2                                Northern NJ Terps TPN  ...     General
# 3    Philly Terps: Young Alumni Happy Hour Summer S...  ...     General
# 4             Philly Terps Suite Night at the Ballpark  ...     General
# ..                                                 ...  ...         ...
# 617                 Baltimore Orioles Bullpen Pregame   ...     General
# 618                                      50th Reunion   ...     Emeriti
# 619                                     Ring Ceremony   ...   Students
# 620                                  Terps on the Hill  ...    General
# 621                NY Terps Alumnae Networking Dinner   ...     Alumnae
#
# [622 rows x 18 columns]

# %%
uniqueValuesArea = datafinal['Area'].unique()
uniqueValuesArea
# Out:
# array(['CP DMV', 'CP Online', 'CP Northeast', 'CP West Coast', 'CP West',
#        'CP Southeast', 'CP DC', 'CP Northeast ', 'CP Social',
#        'CP International', 'CP USA', 'CP Norhteast'], dtype=object)

# %%
datafinal.replace("CP Norhteast", "CP Northeast", inplace=True) #Spelling Error 
datafinal.replace("CP Northeast ", "CP Northeast", inplace=True) # Spacing Error

# %%
uniqueValuesArea = datafinal['Area'].unique()
uniqueValuesArea
# Out:
# array(['CP DMV', 'CP Online', 'CP Northeast', 'CP West Coast', 'CP West',
#        'CP Southeast', 'CP DC', 'CP Social', 'CP International', 'CP USA'],
#       dtype=object)

# %%
uniqueValuesGroup = datafinal['Group'].unique()
uniqueValuesGroup
# Out:
# array(['CP Social', 'CP ProDev', 'CP Athletics', 'CP Prodev',
#        'CP Cultural', 'CP Affinity', 'CP Service', 'CP Advocacy',
#        'CP Affiniy', 'CP General', 'CP D&I', 'CP Career', 'CP Campaign',
#        'CP Pro Dev', 'CP Stewardship', 'CP Cultivation', 'CP DMV',
#        'CP Membership', 'CP Stewarship'], dtype=object)

# %%
datafinal.replace("CP Affiniy", "CP Affinity", inplace=True)
datafinal.replace("CP Stewarship", "CP Stewardship", inplace=True)
datafinal.replace("CP Prodev", "CP ProDev", inplace=True)
datafinal.replace("CP Pro Dev", "CP ProDev", inplace=True)

# %%
uniqueValuesGroup = datafinal['Group'].unique()
uniqueValuesGroup
# Out:
# array(['CP Social', 'CP ProDev', 'CP Athletics', 'CP Cultural',
#        'CP Affinity', 'CP Service', 'CP Advocacy', 'CP General', 'CP D&I',
#        'CP Career', 'CP Campaign', 'CP Stewardship', 'CP Cultivation',
#        'CP DMV', 'CP Membership'], dtype=object)

# %% [markdown]
# ### Data Understanding

# %%
datafinal.dtypes
# Out:
# Event Name                                 object
# Activity Code                              object
# Activity Description                       object
# Location Code                              object
# Location Description                       object
# Group Code                                 object
# Group Description                          object
# Event Date                         datetime64[ns]
# Participated                                int64
# Average Age                                 int64
# First Time Attendees                        int64
# Percentage First Time Attendees           float64
# Major Prospects                             int64
# Percentage Major Prospect                 float64
# Area                                       object
# City                                       object
# Group                                      object
# Type                                       object
# dtype: object

# %%
datafinal.sort_values(by='Event Date', ascending=False)
# Out:
#                                             Event Name  ...      Type
# 69   Tucson Terps: Joint Football Watch Party with ...  ...   General
# 68                                   Football Tailgate  ...   General
# 67                CIVICUS 20th Anniversary Celebration  ...   CIVICUS
# 66                               Leadership Conference  ...   General
# 65                               Patent Primer Webinar  ...   General
# ..                                                 ...  ...       ...
# 612                   Prince George's Terps WBB Suite   ...   General
# 611                             Tampa Day at the Races  ...   General
# 610                                2013 Military Bowl   ...   General
# 609                                        Awards Gala  ...   General
# 608                            2013 Bowl Game Tailgate  ...   General
#
# [622 rows x 18 columns]

# %%
datafinal.tail()
# Out:
#                               Event Name Activity Code  ...        Group        Type
# 617   Baltimore Orioles Bullpen Pregame          PEAOB  ...    CP Social     General
# 618                        50th Reunion          PEZ50  ...    CP Social     Emeriti
# 619                       Ring Ceremony          PEZRC  ...    CP Social   Students
# 620                    Terps on the Hill         PEZTH  ...  CP Advocacy    General
# 621  NY Terps Alumnae Networking Dinner          PEANA  ...    CP ProDev     Alumnae
#
# [5 rows x 18 columns]

# %%
datafinal.head(5)
# Out:
#                                           Event Name  ...     Type
# 0                            Ocean City Summer Party  ...  General
# 1  Neurodiversity on Campus and in the Workplace ...  ...  General
# 2                              Northern NJ Terps TPN  ...  General
# 3  Philly Terps: Young Alumni Happy Hour Summer S...  ...  General
# 4           Philly Terps Suite Night at the Ballpark  ...  General
#
# [5 rows x 18 columns]

# %%
datafinal.describe()
# Out:
#        Participated  Average Age  ...  Major Prospects  Percentage Major Prospect
# count    622.000000   622.000000  ...       622.000000                 622.000000
# mean      44.803859    40.117363  ...         5.966238                   0.102214
# std       93.165049     9.741459  ...        14.123466                   0.131444
# min        1.000000    19.000000  ...         0.000000                   0.000000
# 25%       10.000000    33.000000  ...         0.000000                   0.000000
# 50%       20.000000    40.000000  ...         1.000000                   0.058824
# 75%       44.750000    46.000000  ...         5.000000                   0.166667
# max     1657.000000    75.000000  ...       131.000000                   0.818182
#
# [8 rows x 6 columns]

# %% [markdown]
# ### Checking for Missing Values and Outliers

# %%
np.where(datafinal.isnull() == True)
#datafinal.isnull()
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
numeric_cols = ['Participated','Average Age', 'First Time Attendees', 'Percentage First Time Attendees' , 'Major Prospects', 'Percentage Major Prospect']
datafinal.boxplot(numeric_cols)

# %% [markdown]
# ### Identify all types of events and locations

# %%
uniqueValuesCode = datafinal['Group Code'].unique()
uniqueValuesCode
# Out:
# array(['PS9', 'PC9', 'PSA', 'PSZ', 'PC4', 'PA9', 'PU9', 'PAG', 'PSY',
#        'PQB', 'PQL', 'PO9', 'PUB', 'PCZ', 'PSC', 'PD9', 'PQK', 'P99',
#        'PAZ', 'PVW', 'PCS', 'PAB', 'PUU', 'PAY', 'POB', 'PG9', 'PQX',
#        'PCW', 'PHM', 'PIZ', 'PSL', 'PSS', 'PH9', 'PMM', 'PST', 'PI9',
#        'PCC', 'PUL', 'PS3', 'PUZ', 'PM9', 'PC10', 'PC11', 'POO', 'PSK',
#        'PSB', 'PSO', 'PSX', 'POC'], dtype=object)

# %% [markdown]
# ### Breaking down the date variable

# %%
#Create new dataframe with additional variables 

datafinal['date'] = pd.to_datetime(datafinal['Event Date'],format='%Y%m%d')
datafinal['year'] = pd.DatetimeIndex(datafinal['date']).year
datafinal['month'] = pd.DatetimeIndex(datafinal['date']).month
datafinal['day'] = pd.DatetimeIndex(datafinal['date']).day
datafinal['dayofweek'] = pd.DatetimeIndex(datafinal['date']).day_name()
datafinal

#Code used : https://www.codegrepper.com/code-examples/python/separate+year+and+month+from+date+in+python
# Out:
#                                             Event Name  ...  dayofweek
# 0                              Ocean City Summer Party  ...   Saturday
# 1    Neurodiversity on Campus and in the Workplace ...  ...  Wednesday
# 2                                Northern NJ Terps TPN  ...   Thursday
# 3    Philly Terps: Young Alumni Happy Hour Summer S...  ...   Thursday
# 4             Philly Terps Suite Night at the Ballpark  ...     Sunday
# ..                                                 ...  ...        ...
# 617                 Baltimore Orioles Bullpen Pregame   ...    Tuesday
# 618                                      50th Reunion   ...  Wednesday
# 619                                     Ring Ceremony   ...  Wednesday
# 620                                  Terps on the Hill  ...   Thursday
# 621                NY Terps Alumnae Networking Dinner   ...    Tuesday
#
# [622 rows x 23 columns]

# %%
datafinal.dtypes
# Out:
# Event Name                                 object
# Activity Code                              object
# Activity Description                       object
# Location Code                              object
# Location Description                       object
# Group Code                                 object
# Group Description                          object
# Event Date                         datetime64[ns]
# Participated                                int64
# Average Age                                 int64
# First Time Attendees                        int64
# Percentage First Time Attendees           float64
# Major Prospects                             int64
# Percentage Major Prospect                 float64
# Area                                       object
# City                                       object
# Group                                      object
# Type                                       object
# date                               datetime64[ns]
# year                                        int64
# month                                       int64
# day                                         int64
# dayofweek                                  object
# dtype: object

# %% [markdown]
# ### Simple Data Analysis

# %%
# Analysis 1. Number of Events by year
countyr = datafinal.groupby("year")['Event Name'].agg('count')
print(countyr)

eventsy = datafinal['year'].value_counts()
eventsy.plot(kind='bar')

plt.title('Number of Events per year')
plt.xlabel('Years')
plt.ylabel('Number of Events')
# Out:
# year
# 2013      3
# 2014     54
# 2015     81
# 2016     59
# 2017     45
# 2018    196
# 2019    184
# Name: Event Name, dtype: int64
# Text(0, 0.5, 'Number of Events')

# %%
# Analysis 3. Count by month
countm = datafinal.groupby("month")['Event Name'].agg('count')
print(countm)

eventsm = datafinal['month'].value_counts()
eventsm.plot(kind='bar')

plt.title('Number of Events per month')
plt.xlabel('Month')
plt.ylabel('Number of Events')
# Out:
# month
# 1     36
# 2     66
# 3     75
# 4     83
# 5     37
# 6     38
# 7     19
# 8     29
# 9     54
# 10    82
# 11    66
# 12    37
# Name: Event Name, dtype: int64
# Text(0, 0.5, 'Number of Events')

# %%
datafinal.replace("Norhteast", "Northeast", inplace=True)

# %%
counttype = datafinal.groupby("Group")['Event Name'].agg('count')
print(counttype)

eventsT = datafinal['Group'].value_counts()
eventsT.plot(kind='bar', figsize=(8,4))

plt.title('Number of Events per event type')
plt.xlabel('Event type')
plt.ylabel('Number of Events')
# Out:
# Group
# CP Advocacy        14
# CP Affinity         7
# CP Athletics      138
# CP Campaign         3
# CP Career           1
# CP Cultivation      8
# CP Cultural         8
# CP D&I              1
# CP DMV              1
# CP General          3
# CP Membership       4
# CP ProDev         138
# CP Service         31
# CP Social         244
# CP Stewardship     21
# Name: Event Name, dtype: int64
# Text(0, 0.5, 'Number of Events')

# %%
countplace = datafinal.groupby("Area")['Event Name'].agg('count')
print(countplace)

eventsP = datafinal['Area'].value_counts()
eventsP.plot(kind='bar', figsize=(8,4),color='b')

plt.title('Number of Events per Location')
plt.xlabel('Locations')
plt.ylabel('Number of Events')
# Out:
# Area
# CP DC                 2
# CP DMV              350
# CP International      2
# CP Northeast         79
# CP Online            42
# CP Social             1
# CP Southeast         43
# CP USA                4
# CP West              10
# CP West Coast        89
# Name: Event Name, dtype: int64
# Text(0, 0.5, 'Number of Events')

# %%
"""plt.boxplot([three_sigma(data_DMV['First Time Attendees']),three_sigma(data_Campus['First Time Attendees']),three_sigma(data_Westcoast['First Time Attendees']),three_sigma(data_Southeast['First Time Attendees']),three_sigma(data_Northeast['First Time Attendees']),three_sigma(data_Online['First Time Attendees'])],labels=['DMV','Campus','Westcoast','Southeast','Northeast','Online'])
plt.ylabel('First Time Attendees')
plt.show()
"""
# Out:
# "plt.boxplot([three_sigma(data_DMV['First Time Attendees']),three_sigma(data_Campus['First Time Attendees']),three_sigma(data_Westcoast['First Time Attendees']),three_sigma(data_Southeast['First Time Attendees']),three_sigma(data_Northeast['First Time Attendees']),three_sigma(data_Online['First Time Attendees'])],labels=['DMV','Campus','Westcoast','Southeast','Northeast','Online'])\nplt.ylabel('First Time Attendees')\nplt.show()\n"

# %%
# Analysis 6. average people of year
meanyr = datafinal.groupby("year")['Participated'].agg('mean')
print(meanyr)
# Out:
# year
# 2013    209.000000
# 2014     51.092593
# 2015     54.518519
# 2016     61.610169
# 2017     63.200000
# 2018     36.489796
# 2019     34.972826
# Name: Participated, dtype: float64

# %%
#order by Monday through Sunday
from pandas.api.types import CategoricalDtype
order = CategoricalDtype(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], ordered=True)
datafinal['dayofweek'] =datafinal['dayofweek'].astype(order)

GroupbyDayFT = datafinal.groupby("dayofweek", as_index=True)[["First Time Attendees"]].mean()
print(GroupbyDayFT)
GroupbyDayPFT = datafinal.groupby("dayofweek", as_index=True)[["Percentage First Time Attendees"]].mean()
print(GroupbyDayPFT)
GroupbyDayMJ = datafinal.groupby("dayofweek", as_index=True)[["Major Prospects"]].mean()
print(GroupbyDayMJ)
GroupbyDayPMJ = datafinal.groupby("dayofweek", as_index=True)[["Percentage Major Prospect"]].mean()
print(GroupbyDayMJ)

#Plotting 
plt.figure(figsize=(15,7))
plt.subplot(221)
sns.barplot(x="dayofweek", y="First Time Attendees", data=datafinal, estimator=np.mean, ci=None, color='b')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(223)
sns.barplot(x="dayofweek", y="Percentage First Time Attendees", data=datafinal, estimator=np.mean, ci=None, color='b')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(222)
sns.barplot(x="dayofweek", y="Major Prospects", data=datafinal, estimator=np.mean, ci=None, color='r')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(224)
sns.barplot(x="dayofweek", y="Percentage Major Prospect", data=datafinal, estimator=np.mean, ci=None, color='r')
sns.set(rc = {'figure.figsize':(15,8)})

plt.show()
# Out:
#            First Time Attendees
# dayofweek
# Monday                16.974359
# Tuesday               19.111111
# Wednesday             10.140000
# Thursday              10.898148
# Friday                16.916667
# Saturday              11.628571
# Sunday                16.175000
#            Percentage First Time Attendees
# dayofweek
# Monday                            0.258892
# Tuesday                           0.273882
# Wednesday                         0.268903
# Thursday                          0.275011
# Friday                            0.279918
# Saturday                          0.285137
# Sunday                            0.276311
#            Major Prospects
# dayofweek
# Monday            3.769231
# Tuesday           4.055556
# Wednesday         5.820000
# Thursday          7.203704
# Friday           12.604167
# Saturday          5.674286
# Sunday            3.925000
#            Major Prospects
# dayofweek
# Monday            3.769231
# Tuesday           4.055556
# Wednesday         5.820000
# Thursday          7.203704
# Friday           12.604167
# Saturday          5.674286
# Sunday            3.925000

# %%
GroupbyMonthFT = datafinal.groupby("month", as_index=True)[["First Time Attendees"]].mean()
print(GroupbyMonthFT)

GroupbyMonthMJ = datafinal.groupby("month", as_index=True)[["Major Prospects"]].mean()
print(GroupbyMonthMJ)

#Plotting 
plt.figure(figsize=(15,6))
plt.subplot(221)
sns.barplot(x="month", y="First Time Attendees", data=datafinal, estimator=np.mean, ci=None, color='b')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(223)
sns.barplot(x="month", y="Percentage First Time Attendees", data=datafinal, estimator=np.mean, ci=None, color='b')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(222)
sns.barplot(x="month", y="Major Prospects", data=datafinal, estimator=np.mean, ci=None, color='r')
sns.set(rc = {'figure.figsize':(15,8)})
plt.subplot(224)
sns.barplot(x="month", y="Percentage Major Prospect", data=datafinal, estimator=np.mean, ci=None, color='r')
sns.set(rc = {'figure.figsize':(15,8)})


plt.show()
# Out:
#        First Time Attendees
# month
# 1                  7.722222
# 2                  8.787879
# 3                  9.106667
# 4                 19.397590
# 5                 23.459459
# 6                 10.500000
# 7                 43.368421
# 8                  8.068966
# 9                 12.611111
# 10                13.426829
# 11                 9.454545
# 12                13.189189
#        Major Prospects
# month
# 1             2.444444
# 2             4.681818
# 3             3.960000
# 4             7.542169
# 5             7.918919
# 6             5.815789
# 7             8.684211
# 8             1.827586
# 9             6.277778
# 10            8.792683
# 11            4.454545
# 12            8.243243

# %% [markdown]
# ### Generating A few Pivot Tables

# %%
df_pivotday = pd.pivot_table(datafinal,values="First Time Attendees",index="year",columns="dayofweek",aggfunc=np.mean)
df_pivotday
# Out:
# dayofweek     Monday    Tuesday  Wednesday  ...     Friday   Saturday     Sunday
# year                                        ...
# 2013             NaN        NaN        NaN  ...   0.000000   0.000000        NaN
# 2014        6.000000  18.888889   5.571429  ...  11.000000  29.571429   7.800000
# 2015       32.000000  23.538462  35.125000  ...  20.933333  23.700000  17.875000
# 2016       46.400000   6.833333  18.625000  ...  17.600000  31.642857   9.615385
# 2017       59.200000   6.000000  14.875000  ...  56.000000   7.083333  29.000000
# 2018        5.153846  38.200000   7.390244  ...  20.200000   6.169811  38.681818
# 2019        2.071429   3.421053   4.392857  ...   2.416667   1.574074   1.689655
#
# [7 rows x 7 columns]

# %%
df_pivotmonth = pd.pivot_table(datafinal,values="First Time Attendees",index="month",columns="year",aggfunc=np.mean)
df_pivotmonth
# Out:
# year   2013       2014       2015       2016       2017        2018      2019
# month
# 1       NaN        NaN  10.250000   9.500000   2.000000   15.375000  3.235294
# 2       NaN   0.000000  21.600000   7.000000  19.600000    5.000000  2.115385
# 3       NaN   0.000000  20.500000   9.857143  25.333333    9.250000  1.520000
# 4       NaN   0.000000  12.846154  29.700000   2.142857   41.040000  4.038462
# 5       NaN   0.000000  68.000000  32.625000  65.800000    4.733333  3.000000
# 6       NaN   0.000000  26.000000  25.285714   5.500000   14.428571  3.222222
# 7       NaN        NaN        NaN   0.500000  20.666667  124.833333  1.500000
# 8       NaN  37.000000   8.500000  11.000000        NaN    6.000000  2.090909
# 9       0.0  12.714286  18.250000  68.000000  44.750000    8.500000  2.428571
# 10      0.0  32.538462  21.000000  67.333333   8.500000    8.520000  1.692308
# 11      NaN  17.600000  28.300000  42.000000   5.800000    1.150000  1.526316
# 12      0.0  12.900000  29.125000  16.000000  22.000000    1.692308       NaN

# %%
df_pivotArea = pd.pivot_table(datafinal,values="Percentage First Time Attendees",index="Area",columns="year",aggfunc=np.mean)
print(df_pivotArea)

df_pivotAreaMP = pd.pivot_table(datafinal,values="Percentage Major Prospect",index="Area",columns="year",aggfunc=np.mean)
print(df_pivotAreaMP)
# Out:
# year              2013      2014      2015  ...      2017      2018      2019
# Area                                        ...
# CP DC              NaN       NaN       NaN  ...       NaN       NaN  0.118056
# CP DMV             0.0  0.364236  0.471415  ...  0.341388  0.380091  0.064664
# CP International   NaN       NaN       NaN  ...  0.784091       NaN       NaN
# CP Northeast       NaN  0.335181  0.310842  ...       NaN  0.196839  0.058946
# CP Online          NaN       NaN       NaN  ...  0.391376  0.324127  0.149771
# CP Social          NaN       NaN       NaN  ...       NaN       NaN  0.000000
# CP Southeast       NaN  0.384511  0.351878  ...  0.238619  0.327829  0.048487
# CP USA             NaN       NaN  0.371032  ...       NaN       NaN       NaN
# CP West            NaN       NaN       NaN  ...       NaN  0.317474  0.037037
# CP West Coast      NaN  0.596051  0.503808  ...  0.487518  0.281256  0.093936
#
# [10 rows x 7 columns]
# year                 2013      2014      2015  ...      2017      2018      2019
# Area                                           ...
# CP DC                 NaN       NaN       NaN  ...       NaN       NaN  0.000000
# CP DMV            0.30072  0.136666  0.122575  ...  0.151565  0.112863  0.045804
# CP International      NaN       NaN       NaN  ...  0.000000       NaN       NaN
# CP Northeast          NaN  0.170578  0.215009  ...       NaN  0.098064  0.067268
# CP Online             NaN       NaN       NaN  ...  0.003289  0.049240  0.025723
# CP Social             NaN       NaN       NaN  ...       NaN       NaN  0.066667
# CP Southeast          NaN  0.324194  0.259199  ...  0.220814  0.197505  0.098629
# CP USA                NaN       NaN  0.182788  ...       NaN       NaN       NaN
# CP West               NaN       NaN       NaN  ...       NaN  0.071301  0.083333
# CP West Coast         NaN  0.283732  0.140662  ...  0.040404  0.077050  0.017745
#
# [10 rows x 7 columns]

# %%
df_pivotGroup = pd.pivot_table(datafinal,values="Percentage First Time Attendees",index="Group",columns="year",aggfunc=np.mean)
df_pivotGroup
# Out:
# year            2013      2014      2015  ...      2017      2018      2019
# Group                                     ...
# CP Advocacy      NaN  0.000000       NaN  ...  0.256202  0.233669  0.052941
# CP Affinity      NaN       NaN       NaN  ...       NaN  0.297596  0.064460
# CP Athletics     0.0  0.458790  0.457280  ...  0.155352  0.288092  0.084694
# CP Campaign      NaN       NaN       NaN  ...       NaN       NaN  0.106572
# CP Career        NaN       NaN       NaN  ...       NaN  0.187500       NaN
# CP Cultivation   NaN       NaN  0.621469  ...  0.488636  0.365385  0.052885
# CP Cultural      NaN  0.500000       NaN  ...  0.619048  0.146053  0.070721
# CP D&I           NaN       NaN       NaN  ...       NaN  0.428571       NaN
# CP DMV           NaN       NaN       NaN  ...       NaN       NaN  0.000000
# CP General       NaN       NaN       NaN  ...       NaN  0.761905       NaN
# CP Membership    NaN  0.406780  0.310345  ...       NaN       NaN  0.056338
# CP ProDev        NaN  0.322119  0.368682  ...  0.367592  0.287628  0.096924
# CP Service       NaN  0.500000  0.476111  ...  0.571429  0.303098  0.051111
# CP Social        NaN  0.341165  0.468545  ...  0.405464  0.395295  0.064278
# CP Stewardship   0.0       NaN  0.284942  ...  0.252214  0.244227  0.035229
#
# [15 rows x 7 columns]

# %%
df_pivotGroupMP = pd.pivot_table(datafinal,values="Percentage Major Prospect",index="Group",columns="year",aggfunc=np.mean)
df_pivotGroupMP
# Out:
# year                2013      2014      2015  ...      2017      2018      2019
# Group                                         ...
# CP Advocacy          NaN  0.135593       NaN  ...  0.109852  0.171104  0.069939
# CP Affinity          NaN       NaN       NaN  ...       NaN  0.028846  0.046603
# CP Athletics    0.258433  0.175078  0.151986  ...  0.127769  0.088866  0.036690
# CP Campaign          NaN       NaN       NaN  ...       NaN       NaN  0.114934
# CP Career            NaN       NaN       NaN  ...       NaN  0.000000       NaN
# CP Cultivation       NaN       NaN  0.152542  ...  0.232955  0.057692  0.024038
# CP Cultural          NaN  0.350000       NaN  ...  0.000000  0.000000  0.009009
# CP D&I               NaN       NaN       NaN  ...       NaN  0.015873       NaN
# CP DMV               NaN       NaN       NaN  ...       NaN       NaN  0.066667
# CP General           NaN       NaN       NaN  ...       NaN  0.276190       NaN
# CP Membership        NaN  0.313559  0.298851  ...       NaN       NaN  0.119718
# CP ProDev            NaN  0.143932  0.138131  ...  0.076069  0.126625  0.068119
# CP Service           NaN  0.000000  0.113974  ...  0.000000  0.000000  0.000000
# CP Social            NaN  0.190459  0.142359  ...  0.140022  0.087603  0.037294
# CP Stewardship  0.385294       NaN  0.231965  ...  0.298384  0.226336  0.108226
#
# [15 rows x 7 columns]

# %%
from scipy.stats import chisquare

df=datafinal.apply(lambda x : pd.factorize(x)[0])+1

pd.DataFrame([chisquare(df[x].values,f_exp=df.values.T,axis=1)[0] for x in df])
# Out:
#                0              1   ...            21            22
# 0        0.000000  189347.059676  ...  4.477535e+06  1.496655e+07
# 1    15182.051952       0.000000  ...  2.518117e+06  8.694346e+06
# 2    13688.993269    6629.076132  ...  2.592981e+06  9.111594e+06
# 3   102225.742737   70929.086155  ...  1.863530e+04  1.007015e+05
# 4    83849.313384   59513.449055  ...  2.055418e+05  8.787640e+05
# 5   111080.352956   79563.613767  ...  1.327410e+04  4.969030e+04
# 6    94028.174659   66770.791621  ...  8.073847e+04  3.789720e+05
# 7   216614.405706  369555.905849  ...  4.861066e+06  1.754161e+07
# 8    92874.288583   73504.957301  ...  1.716550e+05  7.089503e+05
# 9   101695.281609   71869.119648  ...  2.843204e+04  1.285195e+05
# 10  108755.400572   78235.427166  ...  2.197587e+04  9.567818e+04
# 11  118145.742770  124737.805349  ...  9.811509e+05  3.350509e+06
# 12  113378.574994   82004.300789  ...  1.212651e+04  3.821766e+04
# 13   89269.094239   73183.989949  ...  4.239069e+05  1.736965e+06
# 14  118867.439219   87216.905383  ...  7.557024e+03  1.951929e+03
# 15   86973.106706   60508.904500  ...  1.425021e+05  6.184190e+05
# 16  118121.624189   86473.957434  ...  7.385079e+03  3.388260e+03
# 17  109739.955654   78823.348020  ...  1.348984e+04  4.694256e+04
# 18  216614.405706  369555.905849  ...  4.861066e+06  1.754161e+07
# 19  118307.606459   86656.310317  ...  7.212492e+03  1.777433e+03
# 20  113423.401719   82056.119194  ...  5.742642e+03  9.062138e+03
# 21  104928.730995   74718.663860  ...  0.000000e+00  8.124755e+04
# 22  117826.205461   86240.946946  ...  6.928729e+03  0.000000e+00
#
# [23 rows x 23 columns]

# %% [markdown]
# ## Complex Analysis - Important Variables

# %%
datafinal.corr(method='pearson')
# Out:
#                                  Participated  Average Age  ...     month       day
# Participated                         1.000000     0.037616  ...  0.019270 -0.002515
# Average Age                          0.037616     1.000000  ...  0.008201  0.074654
# First Time Attendees                 0.835996    -0.048204  ...  0.006804 -0.047270
# Percentage First Time Attendees      0.047840    -0.152633  ...  0.086106 -0.063627
# Major Prospects                      0.658973     0.308342  ...  0.060620  0.044416
# Percentage Major Prospect            0.113415     0.549320  ...  0.007585  0.075520
# year                                -0.109570    -0.057415  ... -0.138539  0.081161
# month                                0.019270     0.008201  ...  1.000000 -0.151735
# day                                 -0.002515     0.074654  ... -0.151735  1.000000
#
# [9 rows x 9 columns]

# %%
"""!pip install dython
from dython import nominal
nominal.associations(datafinal,figsize=(30,20),mark_columns=True);"""
# Out:
# '!pip install dython\nfrom dython import nominal\nnominal.associations(datafinal,figsize=(30,20),mark_columns=True);'

# %%
data_DMV=datafinal[datafinal['Area']=='CP DMV']
data_West=datafinal[datafinal['Area']=='CP West']
data_Southeast=datafinal[datafinal['Area']=='CP Southeast']
data_Northeast=datafinal[datafinal['Area']=='CP Northeast']
data_Online=datafinal[datafinal['Area']=='CP Online']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-829328c1ef7a> in <module>()
# ----> 1 data_DMV=datafinal[datafinal['Area']=='CP DMV']
#       2 data_West=datafinal[datafinal['Area']=='CP West']
#       3 data_Southeast=datafinal[datafinal['Area']=='CP Southeast']
#       4 data_Northeast=datafinal[datafinal['Area']=='CP Northeast']
#       5 data_Online=datafinal[datafinal['Area']=='CP Online']
#
# NameError: name 'datafinal' is not defined

# %%
#clean the extreme outliers
def three_sigma(data,n=3):
    mean=np.mean(data)
    sigma=np.std(data)
    new_data=data.drop(data[abs(data-mean)>3*sigma].index)
    return new_data

# %%
plt.boxplot([three_sigma(data_DMV['First Time Attendees']),three_sigma(data_West['First Time Attendees']),three_sigma(data_Southeast['First Time Attendees']),three_sigma(data_Northeast['First Time Attendees']),three_sigma(data_Online['First Time Attendees'])],labels=['DMV','Campus','Southeast','Northeast','Online'])
plt.ylabel('First Time Attendees')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plt.boxplot([three_sigma(data_DMV['Major Prospects']),three_sigma(data_West['Major Prospects']),three_sigma(data_Southeast['Major Prospects']),three_sigma(data_Northeast['Major Prospects']),three_sigma(data_Online['Major Prospects'])],labels=['DMV','Campus','Southeast','Northeast','Online'])
plt.ylabel('Major Prospects')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plt.boxplot([three_sigma(data_DMV['Percentage First Time Attendees']),three_sigma(data_West['Percentage First Time Attendees']),three_sigma(data_Southeast['Percentage First Time Attendees']),three_sigma(data_Northeast['Percentage First Time Attendees']),three_sigma(data_Online['Percentage First Time Attendees'])],labels=['DMV','West','Southeast','Northeast','Online'])
plt.ylabel('Percentage First Time Attendees')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
plt.boxplot([three_sigma(data_DMV['Percentage Major Prospect']),three_sigma(data_West['Percentage Major Prospect']),three_sigma(data_Southeast['Percentage Major Prospect']),three_sigma(data_Northeast['Percentage Major Prospect']),three_sigma(data_Online['Percentage Major Prospect'])],labels=['DMV','West','Southeast','Northeast','Online'])
plt.ylabel('Percentage Major Prospect')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ### Clustering

# %%
#Do the Kmeans clustering between average age and major prospect and pecentage of it. - Since slightly higher corrrelation than first time attendees 
data=np.array(datafinal[['Average Age','Major Prospects']],dtype='f')
from scipy.cluster.vq import kmeans, vq
# compute k-means with k = 3 (3 clusters)
centroids,_= kmeans(data,3) 
# assign each sample to a cluster
index,_= vq(data,centroids) 
from matplotlib.pyplot import plot, show
# plot different color for each cluster by its index
plot(data[index==0,0],data[index==0,1],'or')
plot(data[index==1,0],data[index==1,1],'ob')
plot(data[index==2,0],data[index==2,1],'om') 
plot(centroids[:,0],centroids[:,1],'sg',markersize=8) 
plt.xlabel('Average age')
plt.ylabel('Major prospects')
plt.show()
#And then see what event can attract people around 40-60

# %%
data_40to60=datafinal.loc[(datafinal['Average Age']>40) &(datafinal['Average Age']<60)]
data_Athletics_40to60=data_40to60[datafinal['Group']=='CP Athletics']
data_ProDev_40to60=data_40to60[datafinal['Group']=='CP ProDev']
data_Social_40to60=data_40to60[datafinal['Group']=='CP Social']
data_Service_40to60=data_40to60[datafinal['Group']=='CP Service']
data_Stewardship_40to60=data_40to60[datafinal['Group']=='CP Stewardship']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
plt.boxplot([three_sigma(data_Service_40to60['Major Prospects']),three_sigma(data_Athletics_40to60['Major Prospects']),three_sigma(data_ProDev_40to60['Major Prospects']),three_sigma(data_Social_40to60['Major Prospects']),three_sigma(data_Stewardship_40to60['Major Prospects'])],labels=['Service','Athletics','ProDev','Social','Stewardship'])
plt.ylabel('Prospects')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#Age less than 40 - event change 
data_40=datafinal.loc[(datafinal['Average Age']<40)]
data_Athletics_40=data_40[datafinal['Group']=='CP Athletics']
data_ProDev_40=data_40[datafinal['Group']=='CP ProDev']
data_Social_40=data_40[datafinal['Group']=='CP Social']
data_Service_40=data_40[datafinal['Group']=='CP Service']
data_Stewardship_40=data_40[datafinal['Group']=='CP Stewardship']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
plt.boxplot([three_sigma(data_Service_40['Major Prospects']),three_sigma(data_Athletics_40['Major Prospects']),three_sigma(data_ProDev_40['Major Prospects']),three_sigma(data_Social_40['Major Prospects']),three_sigma(data_Stewardship_40['Major Prospects'])],labels=['Service','Athletics','ProDev','Social','Stewardship'])
plt.ylabel('Prospects')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# Historic time series graph -- 1st time attendees
import matplotlib.pyplot as plt
datafinal1 = datafinal.sort_values(by = 'Event Date')
plt.figure(figsize=(15,3))
plt.plot('Event Date', 'Percentage First Time Attendees', data=datafinal1, color='b')
plt.title("Changes in Percentage First Time Attendees over time", fontsize=15)
plt.show()

# %%
# Historic time series graph -- 1st time attendees
import matplotlib.pyplot as plt
plt.figure(figsize=(15,3))
plt.plot('Event Date', 'Percentage Major Prospect', data=datafinal1, color='r')
plt.title("Changes in Percentage Major Prospect over time", fontsize=15)
plt.show()

# %%
dtr =pd.date_range('21.09.2013', '30.11.2019')
datafinal.index  = pd.DatetimeIndex(datafinal.index)
datafinal =datafinal.reindex(dtr,fill_value = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-3b3120309be7> in <module>()
#       1 dtr =pd.date_range('21.09.2013', '30.11.2019')
#       2 datafinal.index  = pd.DatetimeIndex(datafinal.index)
# ----> 3 datafinal =datafinal.reindex(dtr,fill_value = 0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4034         kwargs.pop("axis", None)
#    4035         kwargs.pop("labels", None)
# -> 4036         return super().reindex(**kwargs)
#    4037
#    4038     def drop(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4462         # perform the reindex on the axes
#    4463         return self._reindex_axes(
# -> 4464             axes, level, limit, tolerance, method, fill_value, copy
#    4465         ).__finalize__(self, method="reindex")
#    4466
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3881         if index is not None:
#    3882             frame = frame._reindex_index(
# -> 3883                 index, method, copy, level, fill_value, limit, tolerance
#    3884             )
#    3885
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3903             copy=copy,
#    3904             fill_value=fill_value,
# -> 3905             allow_dups=False,
#    3906         )
#    3907
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4530                 fill_value=fill_value,
#    4531                 allow_dups=allow_dups,
# -> 4532                 copy=copy,
#    4533             )
#    4534             # If we've made a copy once, no need to make another one
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1299                     ),
#    1300                 )
# -> 1301                 for blk in self.blocks
#    1302             ]
#    1303
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1299                     ),
#    1300                 )
# -> 1301                 for blk in self.blocks
#    1302             ]
#    1303
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1722         # but are passed the axis depending on the calling routing
#    1723         # if its REALLY axis 0, then this will be a reindex and not a take
# -> 1724         new_values = self.values.take(indexer, fill_value=fill_value, allow_fill=True)
#    1725
#    1726         # Called from three places in managers, all of which satisfy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in take(self, indexer, allow_fill, fill_value)
#    1809         """
#    1810         return NDArrayBackedExtensionArray.take(
# -> 1811             self, indexer, allow_fill=allow_fill, fill_value=fill_value
#    1812         )
#    1813
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/_mixins.py in take(self, indices, allow_fill, fill_value)
#      38     ) -> _T:
#      39         if allow_fill:
# ---> 40             fill_value = self._validate_fill_value(fill_value)
#      41
#      42         new_data = take(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/categorical.py in _validate_fill_value(self, fill_value)
#    1234         else:
#    1235             raise ValueError(
# -> 1236                 f"'fill_value={fill_value}' is not present "
#    1237                 "in this Categorical's categories"
#    1238             )
#
# ValueError: 'fill_value=0' is not present in this Categorical's categories
